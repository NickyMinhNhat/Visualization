# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

path="/content/drive/MyDrive/MAI391/USA_Housing.csv"
df=pd.read_csv(path)

# %%
#Check informations of the dataset(1)
df.head()
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
# Rename the columns of df2_melted: df2_tidy
df = df.rename(columns = {'Avg. Area Income': 'Income', 'Avg. Area House Age': 'HouseAge','Avg. Area Number of Rooms': 'Rooms','Avg. Area Number of Bedrooms': 'Bedrooms','Area Population': 'Population' }, inplace = False)

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Income      5000 non-null   float64
#  1   HouseAge    5000 non-null   float64
#  2   Rooms       5000 non-null   float64
#  3   Bedrooms    5000 non-null   float64
#  4   Population  5000 non-null   float64
#  5   Price       5000 non-null   float64
#  6   Address     5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#               Income     HouseAge  ...    Population         Price
# count    5000.000000  5000.000000  ...   5000.000000  5.000000e+03
# mean    68583.108984     5.977222  ...  36163.516039  1.232073e+06
# std     10657.991214     0.991456  ...   9925.650114  3.531176e+05
# min     17796.631190     2.644304  ...    172.610686  1.593866e+04
# 25%     61480.562388     5.322283  ...  29403.928702  9.975771e+05
# 50%     68804.286404     5.970429  ...  36199.406689  1.232669e+06
# 75%     75783.338666     6.650808  ...  42861.290769  1.471210e+06
# max    107701.748378     9.519088  ...  69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %%
#EDA(2)
sns.heatmap(df.corr(), annot=True)

# %%
sns.set_color_codes()
sns.displot(df['Price'],color="y") 
plt.savefig('Pricedis.pdf')
plt.show()

# %%
sns.jointplot(x="Price", y="Rooms", data=df,color="r");
plt.savefig('PriceRoom.pdf')

# %%
sns.jointplot(x="Price", y="Income", data=df,color="g");
plt.savefig('PriceIncome.pdf')
plt.show()

# %%
sns.jointplot(x="Price", y="Population", data=df,color="m");
plt.savefig('PricePop.pdf')
plt.show()

# %%
sns.set_color_codes()
sns.jointplot(x="Price", y="Rooms", data=df,color="r");
sns.jointplot(x="Price", y="Income", data=df,color="g");
sns.jointplot(x="Price", y="Population", data=df,color="m");
plt.show()

# %%
sns.relplot(
    data=df,
    x="Price", y="Rooms", hue="Bedrooms"
)


sns.relplot(
    data=df,
    x="Price", y="Rooms", hue="HouseAge"
)

# %%
#Check null values of the dataset(3)
df.isnull().sum()
# Out:
# Income        0
# HouseAge      0
# Rooms         0
# Bedrooms      0
# Population    0
# Price         0
# Address       0
# dtype: int64

# %%
sns.boxplot(df['Price'],color="y")
plt.savefig('Pricebox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Rooms'],color="r")
plt.savefig('Roombox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['HouseAge'],color="g")
plt.savefig('Agebox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Bedrooms'],color="m")
plt.savefig('Bedbox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Population'],color="w")
plt.savefig('Popbox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Income'])
plt.savefig('Incomebox1.pdf')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Outlier Analysis(4)
sns.set_color_codes()
fig, axs = plt.subplots(6, figsize = (8,8))
plt1 = sns.boxplot(df['Price'], ax = axs[0],color="y")
print()
plt2 = sns.boxplot(df['Rooms'], ax = axs[1],color="r")
print()
plt3 = sns.boxplot(df['HouseAge'], ax = axs[2],color="g")
print()
plt4 = sns.boxplot(df['Bedrooms'], ax = axs[3],color="m")
print()
plt5 = sns.boxplot(df['Population'], ax = axs[4],color="w")
print()
plt5 = sns.boxplot(df['Income'], ax = axs[5])
print()
plt.savefig('boxd1.pdf')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
# outlier treatment for NUMBER OF Price
sns.set_color_codes()
sns.boxplot(df.Price,color="y" )
Q1 = df.Price .quantile(0.25)
Q3 = df.Price .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Price  >= Q1 - 1.5*IQR) & (df.Price  <= Q3 + 1.5*IQR)]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# outlier treatment for NUMBER OF Rooms
sns.set_color_codes()
sns.boxplot(df.Rooms ,color="r")
Q1 = df.Rooms.quantile(0.25)
Q3 = df.Rooms.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Rooms >= Q1 - 1.5*IQR) & (df.Rooms <= Q3 + 1.5*IQR)]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# outlier treatment for NUMBER OF House Age
sns.set_color_codes()
sns.boxplot(df.HouseAge,color="g" )
Q1 = df.HouseAge .quantile(0.25)
Q3 = df.HouseAge .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.HouseAge  >= Q1 - 1.5*IQR) & (df.HouseAge  <= Q3 + 1.5*IQR)]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# outlier treatment for NUMBER OF Population
sns.set_color_codes()
sns.boxplot(df.Population ,color="m")
Q1 = df.Population .quantile(0.25)
Q3 = df.Population .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Population  >= Q1 - 1.5*IQR) & (df.Population  <= Q3 + 1.5*IQR)]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# outlier treatment for NUMBER OF Income
sns.set_color_codes()
sns.boxplot(df.Income )
Q1 = df.Income .quantile(0.25)
Q3 = df.Income .quantile(0.75)
IQR = Q3 - Q1
df = df[(df.Income  >= Q1 - 1.5*IQR) & (df.Income  <= Q3 + 1.5*IQR)]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(df['Income'])

# %%
#Processiong data(5)
df.columns
# Out:
# Index(['Income', 'HouseAge', 'Rooms', 'Bedrooms', 'Population', 'Price',
#        'Address'],
#       dtype='object')

# %%
X = df[[ 'Rooms', 'HouseAge', 'Bedrooms', 'Population','Income']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
X_train.shape
# Out:
# (3400, 5)

# %%
print('X_train: ', X_train.shape, 'X_test: ', X_test.shape)
print('Y_train: ', y_train.shape, 'Y_test:', y_test.shape)
# Out:
# X_train:  (3400, 5) X_test:  (1458, 5)
# Y_train:  (3400,) Y_test: (1458,)

# %%
print('df: ', df.shape)
# Out:
# df:  (4858, 7)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
# print the intercept
print(lin_reg.intercept_)
# Out:
# 1229563.29363254

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#               Coefficient
# Rooms       116915.959584
# HouseAge    161697.644252
# Bedrooms      3297.101172
# Population  143267.641984
# Income      224062.621088

# %%
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 80509.95079795887
# MSE: 9905571985.663095
# RMSE: 99526.74005343035
# R2 Square 0.9096781347935413
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 81248.28148090768
# MSE: 10232906629.321964
# RMSE: 101157.83029168806
# R2 Square 0.9121264315297866
# __________________________________

# %%
results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(LinearRegression())]], 
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df
# Out:
#                Model           MAE  ...  R2 Square  Cross Validation
# 0  Linear Regression  80509.950798  ...   0.909678          0.910844
#
# [1 rows x 6 columns]
